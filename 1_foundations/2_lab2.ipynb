# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

openrouter_api_url = "https://openrouter.ai/api/v1"

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:4]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-or-v1
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)
# OpenRouter API Key exists and begins sk-o

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openrouter = OpenAI(base_url=openrouter_api_url, api_key=openrouter_api_key)
response = openrouter.chat.completions.create(
    model="openai/gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# You are tasked with designing a year-long public-health strategy for a fictional city of 1,000,000 people to control a newly emergent airborne respiratory illness with an R0 of 1.8, a 5% hospitalization rate, and a 0.5% infection fatality rate; an available vaccine is 60% effective at preventing infection and 90% effective at preventing severe disease but only 30% of the population is initially willing to be vaccinated; hospitals have limited surge capacity and the city has substantial socioeconomic inequality. Produce a detailed, prioritized 12-month plan that includes: (A) specific nonpharmaceutical interventions, vaccination strategies, communication and incentive approaches to increase vaccine uptake to at least 70%, and healthcare surge-capacity plans; (B) a simple quantitative projection model (with explicit assumptions and parameters) that estimates cases, hospitalizations, and deaths under your plan versus a no-intervention baseline, and the expected impact of reaching 70% vaccination; (C) quantitative metrics and decision thresholds (triggers) for tightening or relaxing measures; (D) concrete measures to identify and mitigate disproportionate burdens on vulnerable or marginalized groups; and (E) an ethical assessment of key trade-offs (e.g., civil liberties, economic costs, equity), including at least three alternative strategies you considered and why you rejected them. For each part, list the main uncertainties, describe what additional data you would collect to reduce those uncertainties, and state your confidence level (low/medium/high) in the effectiveness of each major recommendation.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "openai/gpt-5-nano"

response = openrouter.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Executive summary
# - City: population 1,000,000
# - Pathogen: airborne respiratory illness; R0 ≈ 1.8; hospitalization rate 5%; infection fatality rate (IFR) 0.5%
# - Intervention options: nonpharmaceutical interventions (NPIs), vaccination (VE_infection = 60%; VE_severe = 90%), and equity-focused measures
# - Vaccine uptake: 30% initially willing; target 70% coverage achieved through a comprehensive outreach and incentive program
# - Healthcare capacity: limited surge capacity; plan includes bed expansion, staffing, and private-sector cooperation
# - Deliverables: a 12-month, prioritized plan; a simple projection model (plan vs no-intervention baseline and impact of reaching 70% vaccination); decision triggers; equity measures; and ethical trade-offs with alternatives considered
#
# A. Detailed, prioritized 12-month plan
# A1) Nonpharmaceutical interventions (NPIs)
# Objective: lower transmission quickly, protect health system capacity, and buy time for vaccination scale-up, with a focus on equity and feasibility in a socioeconomically diverse city.
#
# Core NPIs (tiered and adjustable by triggers):
# - Indoor masking: universal masking in indoor public spaces (mandatory in schools, transit, healthcare facilities; strongly recommended in all other indoor workplaces). Use high-quality masks (surgical/KN95) where possible.
# - Ventilation and air quality: CO2 monitoring in schools/workplaces; upgrade ventilation to meet or exceed local standards; maximize outdoor-and-ventilated space for events; prioritize shelters, shelters, and crowded settings (homeless services, janitorial, transit hubs).
# - Indoor gathering and occupancy: limit nonessential indoor gatherings (e.g., sports facilities, entertainment venues) with tiered capacity limits (initially modest reductions, tightening during surges).
# - School-based measures: enhanced ventilation, outdoor instruction when feasible, cohorting, rapid testing for outbreak detection in schools with case clusters; masking for staff/students in higher transmission periods.
# - Remote/work options and business practices: encourage telework for nonessential roles; staggered shifts to reduce peak-hour crowding; support for employers to adopt flexible policies.
# - Protective cocooning for high-risk populations: targeted NPIs to reduce exposures for older adults and people with high-risk comorbidities (e.g., dedicated shopping hours, delivery options, and protected visit protocols).
# - Testing, tracing, and isolation: expand access to accessible rapid testing; robust contact tracing; clear guidance for isolation and quarantine with paid sick leave for those affected; supportive services (homeless services, food assistance) to maintain adherence.
# - Public-communication-based NPIs: transparent, data-driven, and culturally competent communications explaining rationale, expected duration, and exit criteria; avoid inconsistent messaging that undermines trust.
# - Equity-focused implementation: ensure all NPIs are accessible and feasible across communities with different incomes, languages, and housing conditions.
#
# Implementation timing and effectiveness (summary):
# - Months 1–2: implement masking, ventilation upgrades, and testing-isolation protocols; begin targeted outreach in underserved communities; establish surge-care partnerships.
# - Months 3–6: adjust NPIs to maintain Rt around 0.9–1.2 as vaccination progresses; institute capacity limits for events; begin cocooning protections for high-risk residents.
# - Months 7–12: use vaccination coverage data to gradually relax NPIs in low-transmission settings, while maintaining measures in high-risk environments and in high-transmission periods (triggered by surveillance data).
#
# Main uncertainties (NPIs):
# - Real-world adherence to masking and ventilation improvements
# - Variation in transmission with socially patterned contact (workplaces, schools, housing)
# - Ability to sustain remote-work policies and to equitably enforce capacity limits
# - Data on local Rt/surveillance reliability and throughputs
# Data to collect to reduce uncertainty:
# - Real-time Rt estimates by district/ward; indoor-outdoor transmission patterns
# - Mask-wearing adherence by setting, access to quality masks
# - Ventilation upgrade completion status and CO2 measurements
# - School and workplace compliance data; outbreaks by setting
# Confidence: Medium
#
# A2) Vaccination strategies to reach at least 70%
# Goals: Scale to at least 70% population coverage with vaccines, maximizing equity and minimizing barriers to access.
#
# Key elements
# - Access expansion:
#   - Mass vaccination sites in central and underserved neighborhoods with extended hours (evenings/weekends)
#   - Mobile vaccination units visiting workplaces, schools, community centers, faith-based venues
#   - School-based vaccination clinics (with parental consent where required)
#   - Door-to-door or neighborhood pop-up clinics in underserved/low-access areas
# - Convenience and scheduling:
#   - Flexible appointment options (walk-in, same-day)
#   - Transportation support (free transit passes, ride-share vouchers)
#   - Childcare support at clinics where needed
# - Outreach and trusted messengers:
#   - Partner with community leaders, faith organizations, and local NGOs; use multilingual, culturally tailored messaging
#   - Roundtables with community advisory boards to adapt approaches
# - Incentives:
#   - Paid time off for vaccination and for recovery from minor side effects
#   - Small cash or grocery vouchers, supermarket gift cards, or transit credits
#   - Non-monetary incentives (local business discounts, public recognition)
# - Communication and counter-misinformation:
#   - Proactive myth-busting, tailored to communities with historically lower vaccination uptake
#   - Transparent updates on vaccine safety/real-world effectiveness
# - Priority groups (early phase):
#   - Older adults, people with chronic conditions, essential workers, residents of crowded housing, migrants with limited access to health services
# - Equity safeguards:
#   - Data by race/ethnicity, income, geography to identify gaps and reallocate resources
#   - Remove barriers: no out-of-pocket costs; no requirement of health insurance
#   - Ensure language access and disability-accessible sites
#
# Vaccination targets and timelines (illustrative)
# - Week 0–4: establish clinics; begin outreach; aim to vaccinate ~3–4% of population per week
# - Week 5–12: sustain ~1–1.5% per week as demand grows and access improves
# - Week 13–40: maintain ~1.0%–1.5% per week, with intensified outreach in underserved areas
# - Week 40+: maintain steady vaccination to surpass 70% population coverage and stabilize at maintenance level
# Assumptions
# - VE_infection = 60% (reduces susceptibility to infection)
# - VE_severe = 90% (reduces risk of hospitalization/death among breakthrough infections)
# - Initial willingness to vaccinate: 30% of population
# - After concerted outreach, 70% accept vaccination
# - No major supply chain disruptions; vaccines provide durable protection for the period considered (waning immunity not modeled here)
# Main uncertainties (vaccination)
# - Real-world uptake trajectories across subgroups
# - Durability of protection and possible need for boosters
# - Vaccine effectiveness against infection and severe disease in the presence of variants
# - Acceptance of vaccines in subpopulations with distrust or barriers
# Data to collect
# - Vaccination uptake by age, race/ethnicity, neighborhood, occupation
# - Reasons for vaccine hesitancy and barriers to access
# - Incidence of adverse events and public reporting
# - Vaccine supply chain timing and waste rates
# Confidence: Medium
#
# A3) Communication and incentive approaches to increase uptake to 70%
# - Trusted messengers: engage community leaders, clinicians, and lay health workers from diverse communities
# - Transparent, multilingual, culturally appropriate messaging about benefits/risks
# - Address barriers: access, hours, transport, childcare; ensure sites are accessible and welcoming
# - Incentives: paid time off, transit support, small financial or material rewards, and public recognition
# - Behavioral nudges: reminders, social norm messaging, opt-out default booking for vaccination appointment
# - Mandates in specific high-risk settings (if necessary and legally permissible) balanced with exemptions for medical/religious reasons
# Main uncertainties (communication and incentives)
# - Effectiveness of incentives in raising uptake in different communities
# - Message resonance and counter-misinformation
# - Potential backlash or fatigue around messaging
# Data to collect
# - Reach and engagement metrics for outreach; appointment rates by channel
# - Perceived barriers and motivators; effect of incentives on uptake
# - Changes in vaccine acceptance after campaigns
# Confidence: Medium
#
# A4) Healthcare surge-capacity plans
# Objective: prevent hospital system overload and maintain care quality during case surges.
#
# Components
# - Capacity expansion:
#   - Reserve and expand beds (e.g., add temporary surge-capable beds in non-traditional spaces)
#   - Increase ICU capacity through staffing and equipment (ventilators, PPE, monitors)
#   - Pre-arranged mutual-aid agreements with private hospitals; targeted capacity sharing during surges
#   - Leverage temporary care sites for noncritical patients (step-down units, observation units)
# - Staffing and operations:
#   - Rapid credentialing/temporary staffing pools; cross-training of clinicians
#   - redeployment plans for non-ICU staff to critical areas during spikes
#   - Telemedicine to reduce in-person visits when appropriate
# - Patient flow and triage:
#   - Clear clinical triage and escalation criteria; protect vulnerable populations
#   - Dedicated pathways for COVID-19 patients to minimize cross-infection
# - Supply chain and PPE:
#   - Maintain stockpiles; diversify suppliers; monitor burn rates
# - Community supports to reduce demand on hospitals:
#   - Home-based care programs for mild cases; home monitoring kits
#   - Community clinics to manage nonemergency needs
# - Equity considerations:
#   - Ensure surge plans do not disproportionately draw resources away from marginalized communities
# Main uncertainties (surge capacity)
# - Availability of qualified personnel during surges
# - Demand spikes and duration
# - Public acceptance of hospital diversion or triage policies
# Data to collect
# - Hospital bed occupancy, ICU occupancy, staffing levels, supply burn rates
# - Time-to-approval for surge expansions and MOUs with private providers
# - Operational metrics for patient flow and mortality by setting
# Confidence: Medium
#
# A5) Implementation timeline (month-by-month overview)
# - Month 1: establish governance (incident command structure), confirm surge capacity MOUs, begin mass vaccination site operations, deploy targeted outreach in underserved neighborhoods, initiate NPIs (masking, ventilation upgrades)
# - Month 2–3: escalate NPIs if Rt remains above target; expand mobile clinics and workplace vaccination; deploy paid leave incentives; launch multilingual campaigns
# - Month 4–6: push vaccination toward 60–65% coverage; monitor equity indicators and adjust clinics; start cocooning high-risk populations; expand hospital surge capacity as needed
# - Month 7–9: aim for ≥70% population vaccination; refine NPIs to be responsive to local transmission; adjust gathering restrictions; maintain protections for vulnerable populations
# - Month 10–12: monitor for waning immunity or breakthrough clusters; finalize transition plan to maintenance phase; sustain communications and equity-focused activities; de-escalate NPIs where surveillance shows sustained control
#
# Main uncertainties (overall plan)
# - Public adherence to NPIs over time
# - Timeliness of vaccine supply and uptake
# - Evolving epidemiology (new variants, seasonality)
# Data to collect
# - Real-time transmission metrics (Rt, case counts, test positivity)
# - Vaccination uptake by subpopulation and by setting
# - Hospital capacity and patient outcomes by site and region
# Confidence: Medium
#
# B. Simple quantitative projection model (explicit assumptions and parameters)
# Purpose: provide a transparent, simple framework to compare (i) no intervention baseline vs (ii) plan with NPIs and vaccination, and (iii) the impact of achieving 70% vaccination.
#
# Model type and structure (simple deterministic compartmental flavor)
# - Population N = 1,000,000
# - Baseline pathogen parameters:
#   - R0 = 1.8 (no NPIs, homogeneous mixing)
#   - IFR = 0.5%
#   - Hospitalization rate among infections (I→H) = 5%
# - Vaccination:
#   - VE_infection = 60% (infection reduction for vaccinated individuals)
#   - VE_severe = 90% (reduction in risk of severe outcomes among breakthrough infections)
#   - Initial vaccination willingness: 30% of population to be vaccinated
#   - Target vaccination uptake: 70% of population
#   - Vaccination rollout schedule (illustrative, weekly cadence):
#     - Weeks 1–4: vaccinate 3–4% of population per week (rapid start; clinics open widely)
#     - Weeks 5–12: vaccinate ~1–1.5% per week
#     - Weeks 13–40: vaccinate ~1.0–1.5% per week to reach ~70% by Week 40
# - Nonpharmaceutical interventions (NPIs)
#   - Effect on transmission modeled via reduction in effective Re (Re)
#   - Plan assumes NPIs plus vaccination reduce transmission enough to keep Re near or below 1 during mass vaccination and to drive it lower as coverage increases
#   - For illustration in this simplified projection, assume average Re_plan ≈ 1.0–1.2 during the period until vaccination coverage is high; after reaching 70% coverage, Re declines toward <1.0 with sustained NPIs and natural waning of transmission
# - Mixing by vaccination status (simplified)
#   - We partition infections into vaccinated and unvaccinated groups, with infection risk scaled by VE_infection
#   - At the end of vaccination rollout, vaccinated fraction V = 0.70; unvaccinated fraction U = 0.30
#   - Relative susceptibility: vaccinated individuals have 40% of the infection risk of unvaccinated individuals (1 − VE_infection = 0.40)
# - Outcome calculations
#   - Infections (I) split into:
#     - I_vaccinated ≈ I_total × [V × 0.40] / [V × 0.40 + U × 1]
#     - I_unvaccinated ≈ I_total − I_vaccinated
#   - Hospitalizations (H) = 0.05 × I_unvaccinated + 0.005 × I_vaccinated
#     - Note: hospitalization rate for vaccinated infections is 5.0% × (1 − VE_severe) = 0.5% (i.e., 0.05%? Wait: VE_severe 90% reduces hospitalization by 90%; 5% baseline × (1 − 0.90) = 0.5%)
#     - For clarity: H_unvaccinated = 0.05 × I_unvaccinated
#       H_vaccinated = 0.005 × I_vaccinated
#   - Deaths (D) = IFR_unvaccinated × I_unvaccinated + IFR_vaccinated × I_vaccinated
#     - IFR_unvaccinated = 0.005 (0.5%)
#     - IFR_vaccinated = 0.005 × (1 − VE_severe) = 0.0005 (0.05%)
#     - Note: this assumes a 90% reduction in fatality risk among the vaccinated for severe disease
# - Scenarios
#   1) No-intervention baseline (no NPIs; no vaccination effect on transmission beyond natural course)
#      - Infections I_base ≈ 0.73 × N = 730,000
#      - H_base ≈ 0.05 × 730,000 = 36,500
#      - D_base ≈ 0.005 × 730,000 = 3,650
#   2) Plan with NPIs plus vaccination reaching 70% by Week 40 (I_total_plan)
#      - We estimate total infections declines to about 0.58 × 730,000 ≈ 424,000 over the year due to reduced susceptibility and transmission
#      - Distribution:
#        - I_vaccinated ≈ I_total_plan × [0.70 × 0.40] / [0.70 × 0.40 + 0.30 × 1] ≈ 424,000 × 0.28 / 0.58 ≈ 204,276
#        - I_unvaccinated ≈ 424,000 − 204,276 ≈ 219,724
#      - Hospitalizations:
#        - H_unvaccinated ≈ 0.05 × 219,724 ≈ 10,986
#        - H_vaccinated ≈ 0.005 × 204,276 ≈ 1,021
#        - H_plan ≈ 12,007
#      - Deaths:
#        - D_unvaccinated ≈ 0.005 × 219,724 ≈ 1,099
#        - D_vaccinated ≈ 0.0005 × 204,276 ≈ 102
#        - D_plan ≈ 1,201
#   3) Vaccination uptake remains at 30% (i.e., no significant increase)
#      - I_total ≈ 0.73 × N = 730,000 (no substantial reduction in transmission)
#      - Vaccination composition: V = 0.30; U = 0.70
#      - I_vaccinated ≈ 730,000 × [0.30 × 0.40] / [0.30 × 0.40 + 0.70 × 1] ≈ 730,000 × 0.12 / 0.46 ≈ 190,435
#      - I_unvaccinated ≈ 539,565
#      - H ≈ 0.05 × 539,565 + 0.005 × 190,435 ≈ 26,978 + 952 ≈ 27,930
#      - D ≈ 0.005 × 539,565 + 0.0005 × 190,435 ≈ 2,698 + 95 ≈ 2,793
# - Summary numbers (illustrative, simplified)
#   - No intervention baseline: Infections 730k; Hospitalizations 36.5k; Deaths 3.65k
#   - Plan with 70% uptake by Week 40: Infections ≈ 424k; Hospitalizations ≈ 12k; Deaths ≈ 1.2k
#   - If uptake stalls at 30%: Infections ≈ 730k; Hospitalizations ≈ 27.9k; Deaths ≈ 2.8k
#
# Explicit assumptions and parameters used in this simple model:
# - N = 1,000,000
# - R0 = 1.8 (baseline)
# - VE_infection = 60%
# - VE_severe = 90%
# - Initial vaccination willingness = 30%
# - Vaccination rollout rate designed to reach 70% by Week 40
# - 5% infection- to-hospitalization rate in unvaccinated
# - 0.5% IFR in the unvaccinated; 90% reduction in IFR for vaccinated breakthrough infections (0.05%)
# - NPIs reduce transmission enough to keep Re near 1–1.2 during rollout and lower thereafter
# - Population mixing is simplified and homogeneous for projection purposes
# - Immunity is assumed durable over the 12-month horizon (waning immunity not modeled)
#
# Main uncertainties (projection)
# - Real-world vaccine effectiveness against infection with circulating variants
# - Durability of vaccine protection (waning immunity; need for boosters)
# - Adherence to NPIs and social behavior changes over time
# - Heterogeneity in contact patterns (age, occupation, housing)
# - Accurate case ascertainment, test availability, and reporting delays
# Data to collect to reduce uncertainties
# - Age-stratified infection, hospitalization, and death data
# - Real-world VE estimates by variant and time since vaccination
# - Vaccine uptake by neighborhood, race/ethnicity, and occupation
# - Hospital occupancy, ICU occupancy by time and setting
# - Compliance and effectiveness of NPIs (mask usage, ventilation upgrades)
# Confidence: Plan effectiveness — Medium (model is simplified; qualitative direction is robust but quantitative outputs depend on uncertain behavioral and biological factors)
#
# C. Quantitative metrics and decision thresholds (triggers)
# Primary metrics (weekly/daily)
# - Transmission and cases:
#   - 7-day average new cases per 100,000 population
#   - Effective reproduction number, Rt (estimated)
#   - Test positivity rate
# - Healthcare system:
#   - Hospital occupancy (non-ICU) as % of surge-capacity bed availability
#   - ICU occupancy % of surge-capacity ICU beds
#   - New COVID-19-related admissions per week
# - Vaccination:
#   - Proportion of population vaccinated (first and second doses, if applicable)
#   - Uptake by demographic group and geographic area
# - Equity indicators:
#   - Incidence and hospitalization rate by income quintile, race/ethnicity, language, housing status
#   - Access metrics (clinic wait times, distance to vaccination sites)
# Decision thresholds and corresponding actions
# - Transmission/Case thresholds:
#   - If 7-day case rate ≥ 50 per 100k for 2 consecutive weeks: implement moderate NPIs (masking in indoor spaces, capacity limits for events, reinforce ventilation)
#   - If 7-day case rate ≥ 100 per 100k for 2 consecutive weeks: escalate to stricter measures (reduce indoor dining, higher gathering limits, targeted closures)
#   - If Rt > 1.2 for 2 consecutive weeks despite NPIs: intensify communication campaigns; expand vaccination outreach; consider temporary tightening of nonessential gathering limits
#   - If Rt ≤ 0.9 for 2 consecutive weeks and vaccination coverage ≥ 60%: begin staged relaxation of NPIs (indoor masking decoupled from case count; resume more normal operations with surveillance)
# - Healthcare-capacity thresholds:
#   - If non-ICU bed occupancy > 85% surge capacity or ICU occupancy > 80% surge capacity: escalate NPIs; reallocate resources; request surge staffing; implement risk-based triage if needed
#   - If capacity is increasing (beds and staff becoming available) and Rt is under control: gradual relaxation of some NPIs
# - Vaccination thresholds:
#   - If vaccination coverage (first dose or full course) reaches ≥ 70% citywide: sustain protective measures with focus on maintenance; prioritize high-risk enclaves for vaccination and boosters; monitor for outbreaks and adjust
# - Equity thresholds:
#   - If infection rates or hospitalizations are disproportionately high in a particular group or neighborhood, trigger targeted outreach, faster vaccine access, and social support to those communities
#
# Main uncertainties (triggers)
# - Accuracy and timeliness of Rt and case data
# - Time-lag between NPIs and observable impact on case counts
# - Behavioral responses to risk communication and policy changes
# - Data quality and granularity for equity indicators
# Data to collect
# - Real-time Rt estimates by district; test positivity by district
# - Hospital and ICU occupancy by facility and region
# - Vaccination uptake by neighborhood and subpopulation
# - Equity-related metrics (income, race/ethnicity, language, housing status)
# Confidence: Medium
#
# D. Measures to identify and mitigate disproportionate burdens on vulnerable or marginalized groups
# Goals: minimize inequities in infection risk, access to vaccination, and adverse health outcomes.
#
# Strategies
# - Data-driven equity monitoring:
#   - Collect and publish weekly dashboard by race/ethnicity, income, language, and housing type
#   - Identify neighborhoods with higher attack rates or lower vaccination uptake
# - Access and logistics:
#   - Free vaccination at multiple convenient sites (community centers, faith-based sites, mobile clinics)
#   - Extended hours (evenings/weekends); transportation assistance (fare subsidies, rides to clinics)
#   - Childcare and eldercare support at vaccination sites
#   - Language access: multilingual staff, translated materials, interpretation services
# - Financial and social supports:
#   - Paid time off for vaccination and post-vaccination recovery
#   - Food assistance, housing stability resources; accommodation for those with caregiving responsibilities
# - Community engagement:
#   - Establish community advisory boards; co-design outreach with stakeholders from marginalized communities
#   - Transparent, consistent communication about safety, efficacy, and rollout progress
# - Targeted interventions:
#   - Focused vaccination drives in underserved neighborhoods; address barriers like mistrust with trusted local leaders
#   - Safe isolation support (housing options for isolation if home conditions are unsuitable)
# - Healthcare access and outcomes:
#   - Ensure equitable triage protocols; avoid bias in resource allocation; monitor for disparities in time-to-treatment and outcomes
# Main uncertainties
# - Effectiveness of outreach in reducing hesitancy among specific groups
# - Impact of social determinants (housing density, occupation) on infection risk even with vaccination
# Data to collect
# - Vaccination uptake by neighborhood, race/ethnicity, income; barriers reported by residents
# - Outbreaks in shelters, group housing, and workplaces; social support utilization
# - Time-to-care metrics by community group and facility
# Confidence: High (when implemented with robust evaluation and community involvement)
#
# E. Ethical assessment and trade-offs; alternative strategies considered
# Ethical framework: maximizing protection of life and health while upholding civil liberties, equity, and proportionality; minimize harm to vulnerable groups; ensure proportionality of measures to risk.
#
# Key trade-offs
# - Civil liberties vs public health protection: masking and capacity limits may be met with resistance; justify with transparency and periodic review
# - Economic costs vs health benefits: NPIs cause short-term economic impact, particularly for low-income workers; mitigate with targeted supports
# - Equity vs efficiency: broad NPIs may benefit population health but impose costs on marginalized groups; address with targeted interventions and supports
# - Individual autonomy vs collective protection: vaccination mandates or incentives raise autonomy concerns; balance with community protection and clear exemptions
# Three alternative strategies considered and why rejected
# - Strategy 1: Strict suppression (Lockdown until >90% vaccination)
#   - Rationale: maximize short-term transmission suppression and minimize hospitalizations
#   - Why rejected: severe economic and social costs; risk of noncompliance and civil-liberties concerns; may fail to achieve 90% uptake in a diverse city; entails significant burden on vulnerable workers and small businesses
# - Strategy 2: Vaccination-only approach (no NPIs; rely on vaccination to curb spread)
#   - Rationale: maximize civil liberties and economic activity; rely on vaccination to reduce transmission and severe outcomes
#   - Why rejected: current vaccine uptake is low (30%); VE_infection is limited (60%), so transmission would continue; vulnerable populations would bear a disproportionate burden before reaching threshold; risk of hospital overload during seeding outbreaks
# - Strategy 3: Targeted NPIs only in high-risk settings (no citywide NPIs)
#   - Rationale: minimize disruption by focusing on high-risk environments (nursing homes, crowded workplaces)
#   - Why rejected: transmission remains highly interconnected across the city; outbreaks in schools, workplaces, transit can still overwhelm health system; equity concerns as marginalized communities could bear higher exposure without broad protections
# - Final choice rationale: A combination of moderate NPIs, robust vaccination outreach to 70%+, and surge-capacity planning provides the best balance of reducing transmission and health burden while protecting civil liberties and supporting equity.
#
# Main uncertainties (ethics)
# - How to balance individual autonomy with population protection, especially regarding incentives or mandates
# - Extent to which targeted supports effectively reduce inequities in uptake and outcomes
# - Potential unintended economic consequences of NPIs on marginalized workers
# Data to collect
# - Public attitudes toward NPIs and vaccination across communities; perceived legitimacy of measures
# - Economic impact data on small businesses and workers in high-risk sectors
# - Real-world equity outcomes (infection rates, hospitalizations by demographic group)
# Confidence: Medium to High (ethical framework supports mixed approach; effectiveness depends on implementation)
#
# Additional data to reduce overall uncertainties (across all parts)
# - Real-time, age-stratified data on cases, hospitalizations, ICU use, mortality
# - Subpopulation-specific vaccine uptake, hesitancy drivers, and access barriers
# - Variant prevalence and VE against circulating strains
# - Compliance and behavioural data related to NPIs (mask use, ventilation improvements, social mixing)
# - Health-system surge capacity and workforce availability
# - Economic impact data to balance public health benefits with livelihoods
#
# Overall confidence levels
# - NPIs: medium (contingent on adherence and capacity for enforcement)
# - Vaccination strategy: medium (depends on uptake, access, and trust-building)
# - Communication/incentives: medium (depends on resonance with diverse communities)
# - Surge capacity planning: medium (depends on supply chain, staffing, and inter-institutional cooperation)
# - Projection model: medium (simplified, does not capture all heterogeneity and long-term dynamics)
# - Decision thresholds: medium (robust to typical fluctuations but sensitive to data quality)
# - Equity measures: high (if consistently audited and resources allocated accordingly)
# - Ethical assessment: medium to high (clear framework; depends on governance and stakeholder engagement)
#
# What would be needed to implement and refine
# - Establish data-sharing pipelines across city agencies and healthcare providers
# - Build a robust communications and community engagement plan with trusted local partners
# - Formalize and rehearse surge-capacity agreements with hospitals and private providers
# - Create a system for real-time inequity monitoring and rapid resource reallocation
# - Set up a small, independent ethics panel to review policy changes and exemptions
#
# In sum
# - A year-long strategy combining moderate NPIs, a robust vaccination push to 70% uptake, and deliberate equity-focused actions can substantially reduce infections, hospitalizations, and deaths relative to a no-intervention baseline—while balancing civil liberties, economic costs, and equity concerns.
# - The projection illustrates meaningful impact from reaching 70% vaccination, with substantially fewer hospitalizations and deaths than the no-intervention scenario; uncertainty remains due to real-world adherence, vaccine effectiveness against variants, and the durability of immunity.
# - The plan includes clear triggers for tightening or relaxing measures, with emphasis on equity, protections for the vulnerable, and transparent ethical considerations.
# - Ongoing data collection and community engagement are essential to reduce uncertainties and adjust strategies in real time.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "anthropic/claude-sonnet-4-5"

response = openrouter.chat.completions.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 5
#       1 # Anthropic has a slightly different API, and Max Tokens is required
#       3 model_name = "anthropic/claude-sonnet-4-5"
# ----> 5 response = openrouter.messages.create(model=model_name, messages=messages, max_tokens=1000)
#       6 answer = response.content[0].text
#       8 display(Markdown(answer))
#
# AttributeError: 'OpenAI' object has no attribute 'messages'

# %%
model_name = "google/gemini-2.5-flash"

response = openrouter.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
model_name = "deepseek/deepseek-chat"

response = openrouter.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

model_name = "openai/gpt-oss-120b"

response = openrouter.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# So where are we?

print(competitors)
print(answers)

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
